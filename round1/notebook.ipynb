# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("data/prices_round_1_day_-1.csv", delimiter=";")
df.head()
# Out:
#    day  timestamp               product  bid_price_1  bid_volume_1  \
# 0   -1          0  INTARIAN_PEPPER_ROOT      10991.0          15.0
# 1   -1          0     ASH_COATED_OSMIUM          NaN           NaN
# 2   -1        100     ASH_COATED_OSMIUM       9984.0          11.0
# 3   -1        100  INTARIAN_PEPPER_ROOT      10994.0           9.0
# 4   -1        200     ASH_COATED_OSMIUM       9985.0          15.0
#
#    bid_price_2  bid_volume_2  bid_price_3  bid_volume_3  ask_price_1  \
# 0          NaN           NaN          NaN           NaN      11006.0
# 1          NaN           NaN          NaN           NaN      10003.0
# 2          NaN           NaN          NaN           NaN      10000.0
# 3      10991.0          21.0          NaN           NaN      11006.0
# 4       9982.0          20.0          NaN           NaN      10001.0
#
#    ask_volume_1  ask_price_2  ask_volume_2  ask_price_3  ask_volume_3  \
# 0          10.0      11009.0          15.0          NaN           NaN
# ...

# %%
values = df["mid_price"].value_counts()
values[0]
# Out:
# np.int64(34)

# %%
root_df = df[df["product"] == "INTARIAN_PEPPER_ROOT"].copy()
osmium_df = df[df['product'] == 'ASH_COATED_OSMIUM'].copy()

time = root_df["timestamp"]
root_mid = root_df["mid_price"]
osmium_mid = osmium_df["mid_price"]

# %%
type(time)
# Out:
# pandas.Series

# %%
plt.plot(time, root_mid)
plt.xlabel("TimeStamp")
plt.ylabel("Price")
plt.title("Root Price Over Time")
plt.show()

# %%
values = osmium_df["mid_price"].value_counts()
values[0]
# Out:
# np.int64(17)

# %%
plt.plot(time, osmium_mid)
plt.xlabel("TimeStamp")
plt.ylabel("Price")
plt.title("Osmium Price Over Time")
plt.show()
